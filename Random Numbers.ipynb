# %%
import random

secretNum = random.randint(1,20)

print(secretNum)
# Out:
# 10

# %%
x = random.randrange(0,101,5)
print(x)
# Out:
# 100

# %%
diceRoll=random.randint(1,6)
print(diceRoll)
# Out:
# 3

# %%
random.getstate()
# Out:
# (3,
#  (3549247745,
#   1373833839,
#   3133111426,
#   1118075184,
#   407992221,
#   1681259639,
#   4244511181,
#   91732025,
#   3303526545,
#   1725154603,
#   3353211998,
#   503804244,
#   1508965069,
#   2268633587,
#   3959738442,
#   351211486,
#   3999350887,
#   1377643266,
#   1633127748,
#   1789980306,
#   4263019781,
#   4216555815,
#   850077897,
#   575652958,
#   1861451584,
#   2468009468,
#   1348977637,
#   277873687,
#   3860754543,
#   1251652742,
#   1115641365,
#   4122011420,
#   1997535920,
#   2708267283,
#   2992606421,
#   4036705673,
#   3844011942,
#   2552457091,
#   3328684028,
#   1418017114,
#   1237353168,
#   2504627816,
#   1133034856,
#   1590224897,
#   3682422812,
#   2422100526,
#   1970154730,
#   266216514,
#   3205026119,
#   4191702787,
#   2360715232,
#   2117918047,
#   257700517,
#   3484929506,
#   716686710,
#   3164326140,
#   1761827434,
#   2682045679,
#   3476462091,
#   2781255594,
#   3317942311,
#   1337132674,
# ...

# %%
temp=input("What temperature is it?")
if temp >= 27:
    print("you should wear some shorts, short sleeves tshirts, slides and sunglusses")
elif temp >= 17:
    print("you shuld wear some jeans a long sleeve tshirt, trainers and a hat")
elif temp <= 10:
    print("you should wear a tracksuit, a jacket, gloves and trainers")
# Out:
# What temperature is it?3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-6eb166f3bf82> in <module>()
#       1 temp=input("What temperature is it?")
# ----> 2 if temp >= 27:
#       3     print("you should wear some shorts, short sleeves tshirts, slides and sunglusses")
#       4 elif temp >= 17:
#       5     print("you shuld wear some jeans a long sleeve tshirt, trainers and a hat")
#
# TypeError: unorderable types: str() >= int()
